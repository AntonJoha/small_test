# %%
from paint import function, getValues
import numpy as np
import matplotlib.pyplot as plt

# %%
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

print(function)

plt.figure()
plt.subplot(211)
plt.plot(t1, function(t1, 2, [1,-2]), 'bo', t2, function(t2, 3, [1,2,-3]), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.savefig('test.png')
# Out:
# <function function at 0x7f71e8528a60>

# %%
print(getValues(100))
plt.figure()
plt.subplot(211)
plt.plot(getValues(25), 'bo')
# Out:
# [ 4.54549476  1.75274124 -2.30574744 -3.82419736 -3.18045963  0.69445089
#   4.25754689  4.04275477 -1.29075639 -4.96074684 -5.34052864  0.48339191
#   5.02347424  3.60675081  0.8798921  -4.49631003 -4.77072293 -1.86776431
#   2.78960194  4.98871514  2.43117672 -2.72490699 -5.02828631 -2.89798543
#   2.47059122  4.86780007  3.85113637 -1.03316754 -4.01324698 -3.71877608
#   0.70352299  4.58371119  3.17897993 -0.34367358 -4.19807708 -4.41160384
#  -0.42704978  3.5265422   5.06433842  1.84727295 -4.04109695 -5.21564423
#  -1.52877656  2.91516998  6.21528604  2.73203781 -2.06387962 -4.93044762
#  -3.49247657  2.08554495  4.31326501  4.09382975 -0.5371508  -5.25610706
#  -4.60429572 -1.36694502  4.42556081  4.98403138 -0.32550539 -3.60909144
#  -5.6187788  -0.42495864  3.69676263  4.66763093  1.7400113  -2.83623204
#  -5.32189133 -2.3532733   2.33596631  4.53924704  3.50403506 -1.82307454
#  -5.63480761 -2.59588546  0.89714842  4.76798118  3.8638174  -0.71614682
#  -3.8800971  -4.66173661 -1.26405675  3.64505281  3.80210014  1.28216295
#  -2.76415377 -4.73359048 -1.77958863  2.76830199  5.03770525  2.97449
#  -2.66769758 -5.33410652 -2.69363513  1.6915946   4.95497138  3.8101853
#  -1.19970903 -4.91113146 -3.62449255  0.36052246]
