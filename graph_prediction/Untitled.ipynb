# %%
from paint import function, getValues, random_guess
import numpy as np
import matplotlib.pyplot as plt

# %%
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

print(function)

plt.figure()
plt.subplot(211)
plt.plot(t1, function(t1, [1,-2]), 'bo', t2, function(t2, [1,2,-3]), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.savefig('test.png')
# Out:
# <function function at 0x7f16ec0ecf70>

# %%
points = 10

v = getValues(points)
t2 = np.arange(0.0,points,0.1)
w = random_guess(v, 4,1000000)
print(w)
plt.figure()
plt.subplot(211)
plt.plot(v, 'bo')
plt.plot(t2, function(t2, w))
# Out:
# [57.26747551776631, -104.6433962674912, 30.616349272404136, -2.2675703173942825]
